# %%
from sklearn.datasets import make_classification
import numpy as np
X, y = make_classification(n_samples=100, n_features=2, n_informative=1, n_redundant=0, n_classes=2, n_clusters_per_class=1, random_state=41, hypercube=False, class_sep=30)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 6))
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='winter', s=100)

# %%
def perceptron(X, y):
    X = np.insert(X, 0, 1, axis=1)
    n_samples, n_features = X.shape
    weights = np.zeros(n_features)
    # print(weights.shape)
    lr = 0.01
    epochs = 1000

    def sigmoid(z):
        return 1 / (1 + np.exp(-z))

    for i in range(epochs):
        idx = np.random.randint(0, n_samples)
        y_pred = sigmoid(weights.dot(X[idx]))
        error = y[idx] - y_pred
        weights += (lr * error * X[idx])

    return weights[0], weights[1:]

# %%
intercept_, coef_ = perceptron(X, y)

# %%
intercept_, coef_
# Out:
# (np.float64(0.853568591973354), array([1.43128062, 0.04217479]))

# %%
m = -(coef_[0]/coef_[1])
b = -(intercept_/coef_[1])

# %%
m, b
# Out:
# (np.float64(-33.9368778738277), np.float64(-20.238835538277723))

# %%
x_input = np.linspace(-3, 3, 100)
y_input = m*x_input + b

# %%
plt.figure(figsize=(10,6))
plt.plot(x_input,y_input,color='red',linewidth=3)
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)

# %%
from sklearn.linear_model import LogisticRegression
lor = LogisticRegression()
lor.fit(X,y)
# Out:
# LogisticRegression()

# %%
m = -(lor.coef_[0][0]/lor.coef_[0][1])
b = -(lor.intercept_/lor.coef_[0][1])

# %%
x_input1 = np.linspace(-3,3,100)
y_input1 = m*x_input + b

# %%
plt.figure(figsize=(10,6))
plt.plot(x_input,y_input,color='red',linewidth=3)
plt.plot(x_input1,y_input1,color='white',linewidth=3)
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)
